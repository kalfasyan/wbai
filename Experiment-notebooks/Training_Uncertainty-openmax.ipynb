# %%
# %reset -f
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config Completer.use_jedi = False

# %%
import sys
sys.path.insert(0,"..")
import torch
# torch.manual_seed(42)
import torch.nn as nn
import torch.optim as optim
import torchaudio
from torch.utils.data import Dataset, ConcatDataset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import datasets, transforms
import libmr
from openmax import compute_train_score_and_mavs_and_dists,fit_weibull,openmax,compute_channel_distances
from sklearn.metrics import balanced_accuracy_score
from tqdm import tqdm
# from tqdm.notebook import tqdm as tqdm
import numpy as np
import pandas as pd

import copy
from losses import *
import time
torchaudio.USE_SOUNDFILE_LEGACY_INTERFACE = False
torchaudio.set_audio_backend('soundfile')
import os
import random
from pathlib import Path

import matplotlib.pyplot as plt
import psutil
import requests

from utils import *
from datasets import *
from models import *

losschoice = 'ce'
num_classes = 2
num_epochs = 30
batch_size = 32
batch_size_val = batch_size * 2
validation_split = .2
shuffle_dataset = True
num_workers = psutil.cpu_count()
random_seed= 42
setting = 'raw'
modeltype = 'wingbeatraw'
normalize = ""#"sample"

# %%
transforms_list = [FilterWingbeat(setting='bandpass')]

if normalize == "whole":
    dmel1 = WingbeatsDataset(dsname="Melanogaster_RL/Y", clean=True,transform=transforms.Compose(transforms_list))
    dsuz1 = WingbeatsDataset(dsname="Suzukii_RL/L", clean=True, transform=transforms.Compose(transforms_list))
    transformed_dataset = ConcatDataset([dmel1, dsuz1])
    trainval_dataloader = DataLoader(transformed_dataset, batch_size=batch_size, num_workers=num_workers)

    mean, std = calc_mean_std_1D(loader=trainval_dataloader)
    transforms_list += [Normalize(mean=mean, std=std, axes=(0,2))]
elif normalize == "sample":
    transforms_list += [Normalize()]
else:
    pass

dmel1 = WingbeatsDataset(dsname="Melanogaster_RL/Z", custom_label=[0], clean=True, transform=transforms.Compose(transforms_list))
dmel2 = WingbeatsDataset(dsname="Melanogaster_RL/Y", custom_label=[0], clean=True, transform=transforms.Compose(transforms_list))
dsuz1 = WingbeatsDataset(dsname="Suzukii_RL/Y",      custom_label=[1], clean=True, transform=transforms.Compose(transforms_list))
dsuz2 = WingbeatsDataset(dsname="Suzukii_RL/X",      custom_label=[1], clean=True, transform=transforms.Compose(transforms_list))

trainsets = [dmel1, dsuz1]
testsets = [dmel2, dsuz2]

transformed_dataset = ConcatDataset(trainsets)
trainval_dataloader = DataLoader(transformed_dataset, batch_size=batch_size, num_workers=num_workers)
train_size = int(0.8 * len(transformed_dataset))
valid_size = len(transformed_dataset) - train_size
train_dataset, valid_dataset = torch.utils.data.random_split(transformed_dataset, [train_size, valid_size])
test_dataset = ConcatDataset(testsets)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size_val, num_workers=num_workers, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size_val, num_workers=num_workers, shuffle=True)

# %%
from IPython.display import Audio
sig = train_dataset[6][0]
plt.plot(sig.T); plt.ylim(-.04,.04)
Audio(sig, rate=8000, autoplay=True)

# %%
if setting.startswith('psd'):
    model = Conv1dNetPSD()
elif modeltype == 'wingbeatraw':
    model = Conv1dNetRAW()
elif modeltype == 'inception':
    model = nn.Sequential(
                    InceptionBlock(
                        in_channels=1, 
                        n_filters=32, 
                        kernel_sizes=[5, 11, 23],
                        bottleneck_channels=32,
                        use_residual=True,
                        activation=nn.ReLU()
                    ),
                    InceptionBlock(
                        in_channels=32*4, 
                        n_filters=32, 
                        kernel_sizes=[5, 11, 23],
                        bottleneck_channels=32,
                        use_residual=True,
                        activation=nn.ReLU()
                    ),
                    nn.AdaptiveAvgPool1d(output_size=1),
                    Flatten(out_features=32*4*1),
                    nn.Linear(in_features=4*32*1, out_features=2))

# %%
if losschoice == 'digamma':
    criterion = edl_digamma_loss
elif losschoice == 'log':
    criterion = edl_log_loss
elif losschoice == 'mse':
    criterion = edl_mse_loss
else:
    criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, betas=(0.9, 0.999))
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, verbose=True)
early_stopping = EarlyStopping(patience=7, verbose=1)

# %%
# train_class_num = 2
# weibull_tail = 20 #20
# weibull_alpha = 2
# weibull_threshold = 0.001

# %% [markdown]
# ## Training

# %%
y_train = [train_dataloader.dataset[i][1] for i in range(len(train_dataloader.dataset))]

# %%
v

# %%
from sklearn.utils import class_weight
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i : weights[i] for i in range(num_classes)}

class_weights = torch.tensor(list(class_weights.values())).cuda()
criterion = nn.CrossEntropyLoss(weight=class_weights.float())
print(class_weights)

# %%
# Choosing whether to train on a gpu
train_on_gpu = torch.cuda.is_available()
print(f'Train on gpu: {train_on_gpu}')# Number of gpus
device = 'cuda'
model = model.to(device, dtype=torch.float)

# Model training
for epoch in range(num_epochs):
    # Going through the training set
    correct_train = 0
    model.train()
    for x_batch,y_batch,path_batch,idx_batch in tqdm(train_dataloader, desc=f'Epoch: {epoch}\tTraining..'):        

        y_batch = torch.as_tensor(y_batch).type(torch.LongTensor)
        x_batch,y_batch = x_batch.cuda(), y_batch.cuda()
        
        optimizer.zero_grad()
        pred = model(x_batch)
        loss = criterion(pred, y_batch)
        loss.backward()
        optimizer.step()
        correct_train += (pred.argmax(axis=1) == y_batch).float().sum().item()

    train_accuracy = correct_train / (len(train_dataloader)*batch_size) * 100.
    # Going through the validation set
    #if epoch != 0: #and epoch % 5 == 0:
    correct_valid = 0
    model.eval()
    scores, labels = [],[]
    with torch.no_grad():
        for x_batch,y_batch,path_batch,idx_batch in tqdm(valid_dataloader, desc='Validating..\t'):

            y_batch = torch.as_tensor(y_batch).type(torch.LongTensor)
            x_batch,y_batch = x_batch.cuda(), y_batch.cuda()

            pred = model(x_batch)

            scores.append(pred)
            labels.append(y_batch)

            val_loss = criterion(pred, y_batch)
            correct_valid += (pred.argmax(axis=1) == y_batch).float().sum().item()
        valid_accuracy = correct_valid / (len(valid_dataloader)*batch_size_val) * 100.
        scheduler.step(val_loss)
        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break

        scores = torch.cat(scores,dim=0).cpu().numpy()
        labels = torch.cat(labels,dim=0).cpu().numpy()
        scores = np.array(scores)[:, np.newaxis, :]
        labels = np.array(labels)

#         # Fit the weibull distribution from training data.
#         print("Fittting Weibull distribution...")
#         try:    
#             _, mavs, dists = compute_train_score_and_mavs_and_dists(train_class_num, valid_dataloader, device, model)
#             categories = list(range(0, train_class_num))
#             weibull_model = fit_weibull(mavs, dists, categories, weibull_tail, "cosine")
#         except:
#             print("Failed to fit Weibull distribution..")
#             continue

#     pred_softmax, pred_softmax_threshold, pred_openmax = [], [], []
#     score_softmax, score_openmax = [], []
#     for score in scores:
#         so, ss = openmax(weibull_model, categories, score, 0.5, weibull_alpha, "cosine")  # openmax_prob, softmax_prob
#         pred_softmax.append(np.argmax(ss))
#         pred_softmax_threshold.append(np.argmax(ss) if np.max(ss) >= weibull_threshold else train_class_num)
#         pred_openmax.append(np.argmax(so) if np.max(so) >= weibull_threshold else train_class_num)
#         score_softmax.append(ss)
#         score_openmax.append(so)

#     print("Evaluation...")
#     print(f"Softmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_softmax)}")
#     print(f"Thr_Softmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_softmax_threshold)}")
#     print(f"Openmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_openmax)}")

    # Printing results
    print(f"Epoch {epoch}: train_acc: {train_accuracy:.2f}% loss: {loss:.3f},  val_loss: {val_loss:.3f} val_acc: {valid_accuracy:.2f}%")
# Out:
# Epoch: 0	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Train on gpu: True
# Epoch: 0	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.50it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 71.56it/s]
# Epoch: 1	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (inf --> 6.962286).  Saving model ...
# Epoch 0: train_acc: 89.43% loss: 0.199,  val_loss: 6.962 val_acc: 40.36%
# Epoch: 1	Training..: 100%|██████████| 758/758 [00:07<00:00, 98.09it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 76.75it/s]
# Epoch: 2	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (6.962286 --> 2.330670).  Saving model ...
# Epoch 1: train_acc: 93.26% loss: 0.070,  val_loss: 2.331 val_acc: 60.26%
# Epoch: 2	Training..: 100%|██████████| 758/758 [00:08<00:00, 91.55it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 70.41it/s]
# Epoch: 3	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (2.330670 --> 0.544374).  Saving model ...
# Epoch 2: train_acc: 94.04% loss: 0.088,  val_loss: 0.544 val_acc: 58.09%
# Epoch: 3	Training..: 100%|██████████| 758/758 [00:08<00:00, 90.34it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 63.35it/s]
# Epoch: 4	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 3: train_acc: 94.67% loss: 0.053,  val_loss: 0.572 val_acc: 72.78%
# Epoch: 4	Training..: 100%|██████████| 758/758 [00:09<00:00, 84.14it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 62.00it/s]
# Epoch: 5	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 4: train_acc: 95.14% loss: 0.128,  val_loss: 2.662 val_acc: 54.37%
# Epoch: 5	Training..: 100%|██████████| 758/758 [00:08<00:00, 91.75it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 74.19it/s]
# Epoch: 6	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 5: train_acc: 95.48% loss: 0.397,  val_loss: 2.467 val_acc: 59.52%
# Epoch: 6	Training..: 100%|██████████| 758/758 [00:07<00:00, 95.33it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 72.79it/s]
# Epoch: 7	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch     7: reducing learning rate of group 0 to 1.0000e-03.
# Epoch 6: train_acc: 95.97% loss: 0.040,  val_loss: 8.477 val_acc: 47.60%
# Epoch: 7	Training..: 100%|██████████| 758/758 [00:08<00:00, 92.24it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 63.55it/s]
# Epoch: 8	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (0.544374 --> 0.162518).  Saving model ...
# Epoch 7: train_acc: 97.38% loss: 0.167,  val_loss: 0.163 val_acc: 96.68%
# Epoch: 8	Training..: 100%|██████████| 758/758 [00:08<00:00, 90.80it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 73.75it/s]
# Epoch: 9	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (0.162518 --> 0.079859).  Saving model ...
# Epoch 8: train_acc: 97.78% loss: 0.011,  val_loss: 0.080 val_acc: 93.82%
# Epoch: 9	Training..: 100%|██████████| 758/758 [00:08<00:00, 92.50it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 74.20it/s]
# Epoch: 10	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 9: train_acc: 98.05% loss: 0.006,  val_loss: 1.038 val_acc: 81.48%
# Epoch: 10	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.58it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 74.86it/s]
# Epoch: 11	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 10: train_acc: 98.14% loss: 0.060,  val_loss: 0.152 val_acc: 93.26%
# Epoch: 11	Training..: 100%|██████████| 758/758 [00:08<00:00, 86.72it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 72.51it/s]
# Epoch: 12	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 11: train_acc: 98.17% loss: 0.016,  val_loss: 0.546 val_acc: 84.70%
# Epoch: 12	Training..: 100%|██████████| 758/758 [00:08<00:00, 91.24it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 61.99it/s]
# Epoch: 13	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch    13: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 12: train_acc: 98.26% loss: 0.005,  val_loss: 1.682 val_acc: 83.98%
# Epoch: 13	Training..: 100%|██████████| 758/758 [00:08<00:00, 94.11it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 56.87it/s]
# Epoch: 14	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 13: train_acc: 98.63% loss: 0.008,  val_loss: 0.115 val_acc: 96.78%
# Epoch: 14	Training..: 100%|██████████| 758/758 [00:08<00:00, 89.88it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 70.43it/s]
# Epoch: 15	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (0.079859 --> 0.023685).  Saving model ...
# Epoch 14: train_acc: 98.54% loss: 0.005,  val_loss: 0.024 val_acc: 97.37%
# Epoch: 15	Training..: 100%|██████████| 758/758 [00:08<00:00, 92.91it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 73.55it/s]
# Epoch: 16	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Validation loss decreased (0.023685 --> 0.008995).  Saving model ...
# Epoch 15: train_acc: 98.71% loss: 0.027,  val_loss: 0.009 val_acc: 97.45%
# Epoch: 16	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.89it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 72.74it/s]
# Epoch: 17	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 16: train_acc: 98.68% loss: 0.004,  val_loss: 0.046 val_acc: 97.50%
# Epoch: 17	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.85it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 72.19it/s]
# Epoch: 18	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 17: train_acc: 98.76% loss: 0.035,  val_loss: 0.156 val_acc: 97.07%
# Epoch: 18	Training..: 100%|██████████| 758/758 [00:08<00:00, 92.20it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 73.27it/s]
# Epoch: 19	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 18: train_acc: 98.71% loss: 0.024,  val_loss: 0.021 val_acc: 95.90%
# Epoch: 19	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.37it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 71.79it/s]
# Epoch: 20	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch    20: reducing learning rate of group 0 to 1.0000e-05.
# Epoch 19: train_acc: 98.66% loss: 0.004,  val_loss: 0.031 val_acc: 96.99%
# Epoch: 20	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.78it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 73.49it/s]
# Epoch: 21	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 20: train_acc: 98.68% loss: 0.043,  val_loss: 0.136 val_acc: 97.24%
# Epoch: 21	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.32it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 74.10it/s]
# Epoch: 22	Training..:   0%|          | 0/758 [00:00<?, ?it/s]
# Epoch 21: train_acc: 98.80% loss: 0.039,  val_loss: 0.099 val_acc: 97.47%
# Epoch: 22	Training..: 100%|██████████| 758/758 [00:08<00:00, 93.63it/s]
# Validating..	: 100%|██████████| 95/95 [00:01<00:00, 71.09it/s]
# Early stopping

# %% [markdown]
# ## Testing

# %% [markdown]
# ### testing on datasets with same conditions

# %%
model = Conv1dNetRAW()

checkpoint = torch.load('../data_created/checkpoint.pt')
model.load_state_dict(checkpoint)

# Choosing whether to train on a gpu
train_on_gpu = torch.cuda.is_available()
device = 'cuda'
print(f'Train on gpu: {train_on_gpu}')# Number of gpus
model = model.to(device, dtype=torch.float)
# Out:
# Train on gpu: True

# %%
dpip = WingbeatsDataset(dsname="Wingbeats/C. pipiens", custom_label=[2], clean=True, transform=transforms.Compose(transforms_list))
test_dataset = ConcatDataset([dmel2, dsuz2, dpip])#([])#, dpip])
test_dataloader = DataLoader(test_dataset, batch_size=batch_size_val, num_workers=num_workers, shuffle=True)
# Out:
# Found 29475 in dataset: Wingbeats/C. pipiens, and 1 label(s): ['C. pipiens']
# Label(s) changed to [2]

# %%
# model = model.to('cpu', dtype=torch.float)
model.eval()
scores, labels = [],[]
with torch.no_grad():
    for x_batch,y_batch,path_batch,idx_batch in tqdm(test_dataloader, desc='testing..\t'):
        y_batch = torch.as_tensor(y_batch).type(torch.LongTensor)
        x_batch,y_batch = x_batch.cuda(), y_batch.cuda()
        pred = model(x_batch)
        scores.append(pred)
        labels.append(y_batch)
    scores = torch.cat(scores,dim=0).cpu().numpy()
    labels = torch.cat(labels,dim=0).cpu().numpy()
    scores = np.array(scores)[:, np.newaxis, :]
    labels = np.array(labels)
# Out:
# testing..	: 100%|██████████| 878/878 [00:05<00:00, 158.12it/s]

# %%
train_class_num = 2
weibull_tail = 160 #20
weibull_alpha = 2
weibull_threshold = 0.9

# %%
try:    
    _, mavs, dists = compute_train_score_and_mavs_and_dists(train_class_num, test_dataloader, device, model)
    categories = list(range(0, train_class_num))
    weibull_model = fit_weibull(mavs, dists, categories, weibull_tail, "cosine")
except:
    print("Failed to fit Weibull distribution..")

# %%
pred_softmax, pred_softmax_threshold, pred_openmax = [], [], []
score_softmax, score_openmax = [], []
for score in scores:
    so, ss = openmax(weibull_model=weibull_model, 
                     categories=categories, 
                     input_score=score, 
                     eu_weight=0.5, 
                     alpha=weibull_alpha, 
                     distance_type="cosine") 
    pred_softmax.append(np.argmax(ss))
    pred_softmax_threshold.append(np.argmax(ss) if np.max(ss) >= weibull_threshold else train_class_num)
    pred_openmax.append(np.argmax(so) if np.max(so) >= weibull_threshold else train_class_num)
    score_softmax.append(ss)
    score_openmax.append(so)
    
print("Evaluation...")
print(f"Softmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_softmax)}")
print(f"Thr_Softmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_softmax_threshold)}")
print(f"Openmax: {balanced_accuracy_score(y_true=labels, y_pred=pred_openmax)}")    

import seaborn as sns
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_true=labels, y_pred=pred_openmax), annot=True, fmt='g')
pd.Series(pred_openmax).value_counts()
# Out:
# Evaluation...
# Softmax: 0.6042329280292998
# Thr_Softmax: 0.5589694110312631
# Openmax: 0.46426859229060574
# 1    37949
# 2    11572
# 0     6660
# dtype: int64

# %%
model_xtractor = SlicedModel(model)

# %%
model_xtractor.eval()
features = []
with torch.no_grad():
    for x_batch,y_batch,path_batch,idx_batch in tqdm(test_dataloader, desc='testing..\t'):
        y_batch = torch.as_tensor(y_batch).type(torch.LongTensor)
        x_batch,y_batch = x_batch.cuda(), y_batch.cuda()
        features.extend([model_xtractor(x_batch).cpu()])
features = np.vstack(features).squeeze()
# Out:
# testing..	: 100%|██████████| 878/878 [00:06<00:00, 138.39it/s]

# %%
y_test = [test_dataloader.dataset[i][1] for i in range(len(test_dataloader.dataset))]

# %%
plt.figure(figsize=(20,14));
import umap
import umap.plot

mapper = umap.UMAP(random_state=seed).fit(features)
# Out:
# [autoreload of decorator failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: contextmanager() requires a code object with 0 free vars, not 3
# ]
# [autoreload of pygments.lexer failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
# TypeError: __class__ assignment: 'combined' object layout differs from 'combined'
# ]
# [autoreload of pygments.token failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
# TypeError: __class__ assignment: '_TokenType' object layout differs from '_TokenType'
# ]
# [autoreload of prompt_toolkit.application.application failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.utils failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.cache failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.filters.base failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.completion failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/completion/__init__.py", line 1, in <module>
#     from .base import (
# ImportError: cannot import name 'ConditionalCompleter'
# ]
# [autoreload of prompt_toolkit.output.vt100 failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.formatted_text.base failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.layout failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/layout/__init__.py", line 93, in <module>
#     from .scrollable_pane import ScrollablePane
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/layout/scrollable_pane.py", line 10, in <module>
#     from .mouse_handlers import MouseHandler, MouseHandlers
# ImportError: cannot import name 'MouseHandler'
# ]
# [autoreload of prompt_toolkit.layout.containers failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/layout/containers.py", line 1385, in <module>
#     _in_insert_mode = vi_insert_mode | emacs_insert_mode
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/filters/base.py", line 32, in __or__
#     return _or_cache[self, other]
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/prompt_toolkit/filters/base.py", line 85, in __missing__
#     assert isinstance(b, Filter), "Expecting filter, got %r" % b
# AssertionError: Expecting filter, got Condition(<function emacs_insert_mode at 0x7f4bde690620>)
# ]
# [autoreload of prompt_toolkit.lexers.pygments failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.layout.utils failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.input.vt100_parser failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.renderer failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.application.dummy failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.widgets.base failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.shortcuts.progress_bar.base failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of prompt_toolkit.shortcuts.prompt failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded
# ]
# [autoreload of parso.python.tokenize failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/parso/python/tokenize.py", line 234, in <module>
#     class Token(NamedTuple):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/typing.py", line 2144, in __new__
#     nm_tpl = _make_nmtuple(typename, types.items())
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/typing.py", line 2113, in _make_nmtuple
#     types = [(n, _type_check(t, msg)) for n, t in types]
# TypeError: NamedTuple('Name', [(f0, t0), (f1, t1), ...]); each t must be a type Got <parso.python.token.TokenTypes object at 0x7f4bde2195c0>.
# ]
# [autoreload of parso.grammar failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/parso/grammar.py", line 13, in <module>
#     from parso.cache import parser_cache, load_module, try_to_save_module
# ImportError: cannot import name 'try_to_save_module'
# ]
# [autoreload of parso.python.parser failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/parso/python/parser.py", line 11, in <module>
#     class Parser(BaseParser):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/parso/python/parser.py", line 49, in Parser
#     'namedexpr_test': tree.NamedExpr,
# AttributeError: module 'parso.python.tree' has no attribute 'NamedExpr'
# ]
# [autoreload of pyparsing failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/pyparsing.py", line 6712, in __get__
#     cls._intern[attrname] = self.fn(cls)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/pyparsing.py", line 6745, in printables
#     return u''.join(filterfalse(unicode.isspace, cls._get_chars_for_ranges()))
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/pyparsing.py", line 6738, in _get_chars_for_ranges
#     for rr in cc._ranges:
# AttributeError: type object 'object' has no attribute '_ranges'
# ]
# [autoreload of matplotlib.colors failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/colors.py", line 1169, in <module>
#     @cbook.deprecation.deprecated('3.2', alternative='TwoSlopeNorm')
# AttributeError: module 'matplotlib.cbook' has no attribute 'deprecation'
# ]
# [autoreload of matplotlib.pyplot failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/pyplot.py", line 463, in <module>
#     @_copy_docstring_and_deprecators(matplotlib.artist.getp)
# AttributeError: module 'matplotlib' has no attribute 'artist'
# ]
# [autoreload of matplotlib.colorbar failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/colorbar.py", line 40, in <module>
#     import matplotlib.artist as martist
# AttributeError: module 'matplotlib' has no attribute 'artist'
# ]
# [autoreload of matplotlib.cm failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/cm.py", line 25, in <module>
#     import matplotlib.colors as colors
# AttributeError: module 'matplotlib' has no attribute 'colors'
# ]
# [autoreload of matplotlib.contour failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/contour.py", line 11, in <module>
#     import matplotlib.path as mpath
# AttributeError: module 'matplotlib' has no attribute 'path'
# ]
# [autoreload of matplotlib.blocking_input failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/blocking_input.py", line 27, in <module>
#     import matplotlib.lines as mlines
# AttributeError: module 'matplotlib' has no attribute 'lines'
# ]
# [autoreload of matplotlib.backend_managers failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/backend_managers.py", line 4, in <module>
#     import matplotlib.widgets as widgets
# AttributeError: module 'matplotlib' has no attribute 'widgets'
# ]
# [autoreload of matplotlib.gridspec failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/gridspec.py", line 21, in <module>
#     import matplotlib._layoutbox as layoutbox
# AttributeError: module 'matplotlib' has no attribute '_layoutbox'
# ]
# [autoreload of matplotlib._constrained_layout failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/_constrained_layout.py", line 51, in <module>
#     import matplotlib._layoutbox as layoutbox
# AttributeError: module 'matplotlib' has no attribute '_layoutbox'
# ]
# [autoreload of matplotlib.image failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
# ...
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/streamplot.py", line 10, in <module>
#     import matplotlib.cm as cm
# AttributeError: module 'matplotlib' has no attribute 'cm'
# ]
# [autoreload of matplotlib.axes._base failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/axes/_base.py", line 17, in <module>
#     import matplotlib.colors as mcolors
# AttributeError: module 'matplotlib' has no attribute 'colors'
# ]
# [autoreload of matplotlib.axis failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/axis.py", line 12, in <module>
#     import matplotlib.artist as martist
# AttributeError: module 'matplotlib' has no attribute 'artist'
# ]
# [autoreload of matplotlib.spines failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/spines.py", line 6, in <module>
#     import matplotlib.transforms as mtransforms
# AttributeError: module 'matplotlib' has no attribute 'transforms'
# ]
# [autoreload of matplotlib.axes._secondary_axes failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/axes/_secondary_axes.py", line 4, in <module>
#     import matplotlib.docstring as docstring
# AttributeError: module 'matplotlib' has no attribute 'docstring'
# ]
# [autoreload of matplotlib.projections.geo failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/projections/geo.py", line 5, in <module>
#     import matplotlib.axis as maxis
# AttributeError: module 'matplotlib' has no attribute 'axis'
# ]
# [autoreload of matplotlib.projections.polar failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/projections/polar.py", line 8, in <module>
#     import matplotlib.axis as maxis
# AttributeError: module 'matplotlib' has no attribute 'axis'
# ]
# [autoreload of mpl_toolkits.mplot3d.axes3d failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 21, in <module>
#     import matplotlib.axes as maxes
# AttributeError: module 'matplotlib' has no attribute 'axes'
# ]
# [autoreload of mpl_toolkits.mplot3d.axis3d failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axis3d.py", line 7, in <module>
#     import matplotlib.transforms as mtransforms
# AttributeError: module 'matplotlib' has no attribute 'transforms'
# ]
# [autoreload of typing_extensions failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ]
# [autoreload of pkg_resources failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/pkg_resources/__init__.py", line 3087, in <module>
#     class RequirementParseError(packaging.requirements.InvalidRequirement):
# AttributeError: module 'pkg_resources._vendor.packaging' has no attribute 'requirements'
# ]
# [autoreload of urllib3.packages.six failed: Traceback (most recent call last):
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 287, in update_class
#     old_obj = getattr(old, key)
#   File "/home/kalfasyan/anaconda3/envs/wbai/lib/python3.6/site-packages/urllib3/packages/six.py", line 92, in __get__
#     setattr(obj, self.name, result)  # Invokes __set__.
# AttributeError: 'NoneType' object has no attribute 'cStringIO'
# ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-db4eca995453> in <module>
# ----> 1 plt.figure(figsize=(20,14));
#       2 import umap
#       3 import umap.plot
#       4
#       5 mapper = umap.UMAP(random_state=seed).fit(features)
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     691                                         frameon=frameon,
#     692                                         FigureClass=FigureClass,
# --> 693                                         **kwargs)
#     694         fig = figManager.canvas.figure
#     695         if figLabel:
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     313     """Create a new figure manager instance."""
#     314     _warn_if_gui_out_of_main_thread()
# --> 315     return _backend_mod.new_figure_manager(*args, **kwargs)
#     316
#     317
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3491         from matplotlib.figure import Figure
#    3492         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493         fig = fig_cls(*args, **kwargs)
#    3494         return cls.new_figure_manager_given_figure(num, fig)
#    3495
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout)
#     327         # do not use property as it will trigger
#     328         self._dpi = dpi
# --> 329         self.bbox = TransformedBbox(self.bbox_inches, self.dpi_scale_trans)
#     330
#     331         self.transFigure = BboxTransformTo(self.bbox)
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/transforms.py in __init__(self, bbox, transform, **kwargs)
#    1026         if not bbox.is_bbox:
#    1027             raise ValueError("'bbox' is not a bbox")
# -> 1028         cbook._check_isinstance(Transform, transform=transform)
#    1029         if transform.input_dims != 2 or transform.output_dims != 2:
#    1030             raise ValueError(
#
# ~/anaconda3/envs/wbai/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _check_isinstance(_types, **kwargs)
#    2249                     ", ".join(names[:-1]) + " or " + names[-1]
#    2250                     if len(names) > 1 else names[0],
# -> 2251                     type_name(type(v))))
#    2252
#    2253
#
# TypeError: 'transform' must be an instance of matplotlib.transforms.Transform, not a matplotlib.transforms.Affine2D

# %%
umap.plot.points(mapper, labels=np.array(y_test), theme='darkred');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-66039bad0bff> in <module>
# ----> 1 umap.plot.points(mapper, labels=np.array(y_test), theme='darkred');
#
# NameError: name 'umap' is not defined
