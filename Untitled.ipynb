# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
import librosa

# %%
def load_data(hdf5_path):
    with h5py.File(hdf5_path, 'r') as hf:
        x = hf.get('x')
        y = hf.get('y')
        video_id_list = hf.get('video_id_list')
        x = np.array(x)
        y = list(y)
        video_id_list = list(video_id_list)
        
    return x, y, video_id_list

def uint8_to_float32(x):
    return (np.float32(x) - 128.) / 128.
    
def bool_to_float32(y):
    return np.float32(y)

hdf5_path = "/home/kalfasyan/data/audio/packed_features/bal_train.h5"
(x, y, video_id_list) = load_data(hdf5_path)
x = uint8_to_float32(x)		# shape: (N, 10, 128)
y = bool_to_float32(y)		# shape: (N, 527)

# %%
x.shape
# Out:
# (22160, 10, 128)

# %%
y.shape
# Out:
# (22160, 527)

# %%
plt.imshow(x[0,:,:])

# %%
plt.plot(x[0,-1,:])

# %%
librosa.stft(x[0,0,:], n_fft=256, hop_length=42, window='hann').shape
# Out:
# (129, 4)

# %%
from IPython.display import Audio

Audio(x[0,1,:], rate=8000, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x[:,0,:].shape
# Out:
# (22160, 128)
